# %%
from gensim.models import Word2Vec, KeyedVectors

# %%
model = KeyedVectors.load_word2vec_format('/Users/vvs/fasttext/ubercorpus.lowercased.lemmatized.word2vec.300d.bz2', binary=False)

# %%
apple=model['яблуко']
apple.shape
apple[:10]
# Out:
# array([-0.180156,  0.012777,  0.043028,  1.321075,  0.557858, -1.005648,
#         0.637006, -0.137398, -1.518194,  0.783451], dtype=float32)

# %%
model.most_similar('яблуко')
# Out:
# [('помідор', 0.6077929139137268),
#  ('полуниця', 0.6052650809288025),
#  ('апельсин', 0.6038171052932739),
#  ('персик', 0.6007049679756165),
#  ('кавун', 0.5871126651763916),
#  ('ананас', 0.5810573101043701),
#  ('інжир', 0.5727319121360779),
#  ('банан', 0.5713764429092407),
#  ('диня', 0.5633497834205627),
#  ('ягода', 0.5631189942359924)]

# %%
model.most_similar('заступник')
# Out:
# [('помічник', 0.6567573547363281),
#  ('заст.', 0.6548857688903809),
#  ('радник', 0.6105005741119385),
#  ('**заступник', 0.5974134206771851),
#  ('віце-', 0.5940673351287842),
#  ('екс-заступник', 0.5932910442352295),
#  ("віце-прем'єр-міністр", 0.5679771304130554),
#  ("віце-прем'єр", 0.5654737949371338),
#  ('замом', 0.5410760641098022),
#  ('секретар', 0.535107433795929)]

# %%
model.most_similar('комісар')
# Out:
# [('комісаріат', 0.5849514603614807),
#  ('єврокомісар', 0.5818860530853271),
#  ('генсек', 0.5136544108390808),
#  ('нарком', 0.4903629720211029),
#  ('секретар', 0.48245811462402344),
#  ('командувач', 0.479561984539032),
#  ('начальник', 0.47887396812438965),
#  ('аташе', 0.4773103594779968),
#  ('головнокомандувач', 0.474170982837677),
#  ('комендант', 0.4658527970314026)]

# %%
model.most_similar('солея')
# Out:
# [('сульфат', 0.7449857592582703),
#  ('фосфат', 0.7319445610046387),
#  ('карбонат', 0.7300058603286743),
#  ('натрій', 0.7200970649719238),
#  ('хлорид', 0.7185835838317871),
#  ('калій', 0.7161937952041626),
#  ('кальцій', 0.7104215025901794),
#  ('оксид', 0.709677517414093),
#  ('сульфатний', 0.7032346725463867),
#  ('фтор', 0.6974948644638062)]

# %%
model.most_similar('сіль')
# Out:
# [('сода', 0.6595507860183716),
#  ('селітра', 0.6540664434432983),
#  ('вапно', 0.6438677310943604),
#  ('солея', 0.6116940975189209),
#  ('смолити', 0.6104274988174438),
#  ('сірка', 0.5963289141654968),
#  ('желатин', 0.5935289859771729),
#  ('борошно', 0.5912392139434814),
#  ('ропа', 0.5909976959228516),
#  ('йодований', 0.5904694199562073)]

# %%
model.most_similar('130')
# Out:
# [('160', 0.9422574043273926),
#  ('140', 0.9343043565750122),
#  ('170', 0.9271777868270874),
#  ('120', 0.9217559099197388),
#  ('150', 0.9201764464378357),
#  ('110', 0.9145549535751343),
#  ('230', 0.909703254699707),
#  ('250', 0.9033645987510681),
#  ('350', 0.9029508829116821),
#  ('80', 0.8977508544921875)]

# %%
model.most_similar("'''мойсей")
# Out:
# [("'''яків", 0.8487780094146729),
#  ("'''йосип", 0.8409709930419922),
#  ("'''юхим", 0.8339609503746033),
#  ("'''семен", 0.8296088576316833),
#  ("'''матвій", 0.8219156861305237),
#  ("'''борис", 0.8214219212532043),
#  ("'''степан", 0.8186326622962952),
#  ("'''павло", 0.816243588924408),
#  ("'''леонід", 0.8127902150154114),
#  ("'''георгій", 0.8120390176773071)]

# %%
model.most_similar('1945')
# Out:
# [('1944', 0.9549906849861145),
#  ('1943', 0.9296212196350098),
#  ('1941', 0.9238922595977783),
#  ('1942', 0.9205949306488037),
#  ('1940', 0.9194150567054749),
#  ('1946', 0.9155560731887817),
#  ('1947', 0.8969054222106934),
#  ('1939', 0.8929780721664429),
#  ('1948', 0.8694175481796265),
#  ('1938', 0.8676775097846985)]

# %%
model.most_similar('так-так-так')
# Out:
# [('всміхаючись', 0.4533786177635193),
#  ('підбадьорливо', 0.446797639131546),
#  ('карнач', 0.4432711899280548),
#  ('докірливо', 0.44054415822029114),
#  ('пронизливо', 0.43669193983078003),
#  ('цибатий', 0.43472176790237427),
#  ('ну-ну', 0.43291935324668884),
#  ('знехотя', 0.42889824509620667),
#  ('журливо', 0.4277465045452118),
#  ('зніяковіло', 0.4245501756668091)]

# %%
model.most_similar('коронавірус')
# Out:
# [('коронавірусом', 0.7643998861312866),
#  ('mers', 0.7454754114151001),
#  ('коронавірусу', 0.7347201108932495),
#  ('коронавіруса', 0.6883593201637268),
#  ('mers-cov', 0.6603384613990784),
#  ('бвве', 0.6297851800918579),
#  ('вірус', 0.6227158308029175),
#  ('бврс-ков', 0.6222041845321655),
#  ('**вірус', 0.6196790337562561),
#  ('ботулізм', 0.6122599244117737)]

# %%
model.similarity('корупція', 'гроші')
# Out:
# 0.08829947

# %%
model.similarity('корупція', 'крадіжка')
# Out:
# 0.24718075

# %%
model.similarity('корупція', 'злочин')
# Out:
# 0.34824783

# %%
model.most_similar('корупція')
# Out:
# [('хабарництво', 0.7077262997627258),
#  ('рейдерство', 0.6604000329971313),
#  ('корупційний', 0.6128209233283997),
#  ('наркозлочинністю', 0.6078665256500244),
#  ('злочинність', 0.6067655682563782),
#  ('корумпованість', 0.6021299362182617),
#  ('корупцією**', 0.5917408466339111),
#  ('бандитизм', 0.5869929790496826),
#  ('кумівство', 0.5854936242103577),
#  ('інтернет-піратство', 0.585324764251709)]

# %%
model.most_similar('корупцією**')
# Out:
# [('наркозлочинністю', 0.853600800037384),
#  ('інакодумством', 0.7827503681182861),
#  ('корупцiєю', 0.7811568975448608),
#  ('**вільна', 0.7608552575111389),
#  ('інтернет-піратство', 0.7463514804840088),
#  ('контрбатарейну', 0.7347556352615356),
#  ('терроризмом', 0.6751744747161865),
#  ('злочиннiстю', 0.6529297828674316),
#  ('контрбатарейної', 0.6508305668830872),
#  ('органiзованою', 0.6356639862060547)]

# %%
model.most_similar('злочинність')
# Out:
# [('оргзлочинність', 0.6509469747543335),
#  ('корупція', 0.6067655682563782),
#  ('кіберзлочинність', 0.6033808588981628),
#  ('наркоманія', 0.5704510807991028),
#  ('наркоторгівля', 0.5220472812652588),
#  ('наркозлочинністю', 0.5217176675796509),
#  ('бандитизм', 0.5202336311340332),
#  ('наркобізнес', 0.5046727657318115),
#  ('наркотрафік', 0.5029188394546509),
#  ('піратство', 0.4962625503540039)]

# %%
model.most_similar('злочин')
# Out:
# [('правопорушення', 0.7544951438903809),
#  ('діяння', 0.686436116695404),
#  ('злодіяння', 0.6711354851722717),
#  ('злочинів**', 0.6681942939758301),
#  ('проступок', 0.6555019617080688),
#  ('наркозлочинів', 0.608433723449707),
#  ('злочинiв', 0.5984039902687073),
#  ('вбивство', 0.5959606170654297),
#  ('убивство', 0.5901937484741211),
#  ('розбій', 0.578276515007019)]

# %%
model.most_similar('піратство')
# Out:
# [('тероризм', 0.6425415277481079),
#  ('інтернет-піратство', 0.628267765045166),
#  ('браконьєрство', 0.5907787680625916),
#  ('кіберзлочин', 0.5877262949943542),
#  ('корупція', 0.5708097815513611),
#  ('біотероризм', 0.5612677335739136),
#  ('рейдерство', 0.5542953610420227),
#  ('наркоторгівля', 0.5463762283325195),
#  ('корупцією**', 0.5374058485031128),
#  ('екстремізм', 0.5262119174003601)]

# %%
model.most_similar('екстремізм')
# Out:
# [('ксенофобія', 0.7291609644889832),
#  ('сепаратизм', 0.7236125469207764),
#  ('тероризм', 0.7031415700912476),
#  ('антисемітизм', 0.6840896606445312),
#  ('неонацизм', 0.6754924654960632),
#  ('гомофобія', 0.6580566167831421),
#  ('расизм', 0.6512001752853394),
#  ('ісламофобія', 0.6466720104217529),
#  ('радикалізм', 0.6408641338348389),
#  ('сектантство', 0.6133883595466614)]

# %%
model.most_similar(positive=['помідор', 'яблуко'], negative=['фрукт'])
# Out:
# [('цукіні', 0.5096316933631897),
#  ('редиска', 0.508506715297699),
#  ('апельсин', 0.5059472322463989),
#  ('яблучко', 0.5042394399642944),
#  ('огірок', 0.5005896091461182),
#  ('стручок', 0.49934130907058716),
#  ('картоплина', 0.4977259635925293),
#  ('полуниця', 0.49757784605026245),
#  ('гарбуз', 0.49570560455322266),
#  ('морквина', 0.49319374561309814)]

# %%
model.most_similar(positive=['помідор', 'фрукт'], negative=['яблуко'])
# Out:
# [('овоч', 0.719765841960907),
#  ('томат', 0.6370479464530945),
#  ('огірок', 0.631463885307312),
#  ('морепродукти', 0.5971340537071228),
#  ('цитрусовий', 0.5820566415786743),
#  ('цитрусові', 0.5818758010864258),
#  ('баклажан', 0.5770792365074158),
#  ('броколі', 0.5750016570091248),
#  ('морква', 0.5720853805541992),
#  ('капуста', 0.569859504699707)]

# %%
l = "помідор редиска яблучко картопля морква апельсин".split()
model.doesnt_match(l)
# Out:
# 'яблучко'

# %%
l = "помідор редиска картопля морква апельсин".split()
model.doesnt_match(l)
# Out:
# 'апельсин'

# %%
l = "помідор редиска картопля морква".split()
model.doesnt_match(l)
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages/gensim/models/keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)
# 'картопля'

# %%
model.most_similar('гагарін')
# Out:
# [('маленченко', 0.7057149410247803),
#  ('маленченка', 0.6869155764579773),
#  ('долгорукий', 0.6503409147262573),
#  ('лончаков', 0.6496618986129761),
#  ('богатиков', 0.6219677329063416),
#  ('норштейн', 0.6205816268920898),
#  ('долгорукому', 0.6122621297836304),
#  ('збанацький', 0.6107122898101807),
#  ('цурило', 0.6103023290634155),
#  ('тішков', 0.6057983636856079)]

# %%
model.most_similar('депутат')
# Out:
# [('нардеп', 0.7813215255737305),
#  ('обранець', 0.7446150779724121),
#  ('депутат-мажоритарник', 0.7069047093391418),
#  ('парламентарій', 0.6925938129425049),
#  ('депутат-регіонал', 0.6799324154853821),
#  ('депутат-комуніст', 0.6700586676597595),
#  ('депутатка', 0.6564559936523438),
#  ('парламентар', 0.6436043977737427),
#  ('бютівець', 0.6226213574409485),
#  ('депутат-соціаліст', 0.6127516031265259)]

# %%
model.most_similar('порошенко')
# Out:
# [('поршенко', 0.6873558759689331),
#  ('симоненко', 0.6842983961105347),
#  ('ющенко', 0.678443431854248),
#  ('порошенко**', 0.6479908227920532),
#  ('**порошенко', 0.6394093632698059),
#  ('яценюк', 0.6209511160850525),
#  ('мехед', 0.6074249744415283),
#  ('янукович', 0.5862138271331787),
#  ('авен', 0.5838701725006104),
#  ('литвин', 0.5789031982421875)]

# %%
model.most_similar(positive=['ляшко', 'космонавт'], negative=['гагарін'])
# Out:
# [('тягнибок', 0.5803816914558411),
#  ('надоша', 0.47613832354545593),
#  ('канівець', 0.47429102659225464),
#  ('гелевея', 0.46823379397392273),
#  ('зарубінський', 0.46740293502807617),
#  ('березюк', 0.4649885296821594),
#  ('мандюк', 0.46361029148101807),
#  ('царьов', 0.45911234617233276),
#  ('ляшка**', 0.45291441679000854),
#  ('зарубінським', 0.4524950385093689)]

# %%
model.most_similar(positive=['кішка', 'гавкати'], negative=['собака'])
# Out:
# [('гарчати', 0.6170569062232971),
#  ('скавучати', 0.5687792897224426),
#  ('нявкати', 0.5666829347610474),
#  ('скавчати', 0.5557686686515808),
#  ('муркотіти', 0.5494660139083862),
#  ('загавкати', 0.5381675362586975),
#  ('вити', 0.5378968715667725),
#  ('верещати', 0.5361211895942688),
#  ('скавуліти', 0.5286816358566284),
#  ('муркотати', 0.5218373537063599)]

# %%
model.most_similar('кішка')
# Out:
# [('коти', 0.7902022004127502),
#  ('собака', 0.7491377592086792),
#  ('кицька', 0.7334357500076294),
#  ('кіт', 0.7247881889343262),
#  ('кошеня', 0.7066953182220459),
#  ('цуценя', 0.691178560256958),
#  ('песик', 0.6872197985649109),
#  ('собачка', 0.6805952191352844),
#  ('пес', 0.6735959053039551),
#  ('киця', 0.669205367565155)]

# %%
model.most_similar('гавкати')
# Out:
# [('гарчати', 0.7599546909332275),
#  ('скавучати', 0.7325179576873779),
#  ('загавкати', 0.7150952219963074),
#  ('нявкати', 0.6955333352088928),
#  ('скавчати', 0.677462100982666),
#  ('вити', 0.6583197116851807),
#  ('гавкнути', 0.6472156047821045),
#  ('скавуліти', 0.6408728361129761),
#  ('верещати', 0.6359349489212036),
#  ('завалувати', 0.6109115481376648)]

# %%
model.most_similar('я')
# Out:
# [('ти', 0.8001915216445923),
#  ('ви', 0.7909777164459229),
#  ('ми', 0.7572417855262756),
#  ('він', 0.6850168704986572),
#  ('вона', 0.6650839447975159),
#  ('**я', 0.6157548427581787),
#  ('володько', 0.580039918422699),
#  ('мама', 0.5798506140708923),
#  ('_я', 0.5683510899543762),
#  ('хтось', 0.5496849417686462)]

# %%
model.most_similar('також')
# Out:
# [('відтак', 0.6043498516082764),
#  ('потім', 0.5007960200309753),
#  ('саме', 0.47889822721481323),
#  ('точніше', 0.4785543978214264),
#  ('отже', 0.4651528000831604),
#  ('по-друге', 0.4609230160713196),
#  ('зокрема', 0.4595572054386139),
#  ('згодом', 0.4568154811859131),
#  ('заодно', 0.4525581896305084),
#  ('водночас', 0.41283780336380005)]

# %%
model.most_similar('дупа')
# Out:
# [('пика', 0.6249991655349731),
#  ('срака', 0.6183058023452759),
#  ('зад', 0.6135184168815613),
#  ('цицька', 0.5832488536834717),
#  ('задницю', 0.5822055339813232),
#  ('гузно', 0.5667267441749573),
#  ("п'ятірня", 0.5655148029327393),
#  ('фізіономія', 0.5542945861816406),
#  ('морда', 0.5539179444313049),
#  ('мармиза', 0.5487842559814453)]

# %%
model.most_similar(positive=['жінка', 'дупа'], negative=['чоловік'])
# Out:
# [('цицька', 0.5478148460388184),
#  ('пика', 0.5427928566932678),
#  ('сідниця', 0.5307674407958984),
#  ('долонька', 0.5235114097595215),
#  ("п'ятірня", 0.5162308812141418),
#  ('стерво', 0.5066081285476685),
#  ('срака', 0.4983186721801758),
#  ('зад', 0.49197936058044434),
#  ('гузно', 0.4897492527961731),
#  ('мразь', 0.4883926808834076)]

# %%
model.most_similar(positive=['жінка', 'волосся'], negative=['чоловік'])
# Out:
# [('шкіра', 0.639514684677124),
#  ('ніготь', 0.6308958530426025),
#  ('локон', 0.6214256286621094),
#  ('борода', 0.6133123636245728),
#  ('шевелюра', 0.602450966835022),
#  ('дреди', 0.5804580450057983),
#  ('вія', 0.5632258653640747),
#  ('шерсть', 0.5573265552520752),
#  ('вуса', 0.5509917736053467),
#  ('сивина', 0.5433328151702881)]

# %%
model.most_similar(positive=['жінка', 'губа'], negative=['чоловік'])
# Out:
# [('губити', 0.592216968536377),
#  ('щока', 0.5857903361320496),
#  ('повіка', 0.5617272257804871),
#  ('долоня', 0.5430381298065186),
#  ('повіки', 0.5279048681259155),
#  ('лобок', 0.5278220176696777),
#  ('литка', 0.5132076740264893),
#  ('ніздрі', 0.503764808177948),
#  ('вилиця', 0.5036826133728027),
#  ('вія', 0.5029406547546387)]

# %%
model.most_similar(positive=['чоловік', 'голова'], negative=['жінка'])
# Out:
# [('глава', 0.6423991918563843),
#  ('очільник', 0.608640193939209),
#  ('**голова', 0.6039857864379883),
#  ('секретар', 0.6006761193275452),
#  ('керівник', 0.59913170337677),
#  ('екс-голова', 0.5688796043395996),
#  ('начальник', 0.5297656059265137),
#  ('співголова', 0.521258533000946),
#  ('директор', 0.5116923451423645),
#  ('гендиректор', 0.5058269500732422)]

# %%
model.most_similar(positive=['жінка', 'мужність'], negative=['чоловік'])
# Out:
# [('відвага', 0.6889668703079224),
#  ('хоробрість', 0.6592833995819092),
#  ('героїзм', 0.6295052766799927),
#  ('сміливість', 0.6221798658370972),
#  ('доблесть', 0.6016584634780884),
#  ('самовідданість', 0.5879976749420166),
#  ('жертовність', 0.5818215608596802),
#  ('незламність', 0.5755444169044495),
#  ('самопожертва', 0.5726354122161865),
#  ('безстрашність', 0.5714318752288818)]

# %%
model.most_similar(positive=['чоловік', 'краса'], negative=['жінка'])
# Out:
# [('чарівність', 0.563249945640564),
#  ('граціозність', 0.524584949016571),
#  ('пишнота', 0.5170972347259521),
#  ('неповторність', 0.5061290264129639),
#  ('пишність', 0.5013548731803894),
#  ('врода', 0.4969775676727295),
#  ('первозданність', 0.4956086277961731),
#  ('велич', 0.4925747513771057),
#  ('чарівливість', 0.48599207401275635),
#  ('красота', 0.4813266396522522)]

# %%
model.most_similar(positive=['чоловік', 'красота'], negative=['жінка'])
# Out:
# [('славное', 0.504770040512085),
#  ('горы', 0.4765893816947937),
#  ('красотами', 0.4736263155937195),
#  ('огромное', 0.4729456901550293),
#  ('человечеству', 0.47149112820625305),
#  ('веселый', 0.47120553255081177),
#  ('молодость', 0.4711395502090454),
#  ('исцелений', 0.47057774662971497),
#  ('украшение', 0.4686520993709564),
#  ('деревянный', 0.46799027919769287)]

# %%
model.most_similar('красота')
# Out:
# [('краса', 0.6103968024253845),
#  ('красоты', 0.5291791558265686),
#  ('красотами', 0.5186302661895752),
#  ('пишнота', 0.5133168697357178),
#  ('светом', 0.5114133358001709),
#  ('человеческую', 0.511333167552948),
#  ('исцелений', 0.5111333131790161),
#  ('твое', 0.5105879306793213),
#  ('веселый', 0.5085996389389038),
#  ('благодати', 0.5084981918334961)]

# %%
model.most_similar('исцелений')
# Out:
# [('исцеления', 0.8593931198120117),
#  ('божественное', 0.8394932746887207),
#  ('избавления', 0.8389177322387695),
#  ('святое', 0.8371306657791138),
#  ('дары', 0.8364195823669434),
#  ('_яко', 0.8313273191452026),
#  ('знамения', 0.8295415639877319),
#  ('воздержание', 0.8288144469261169),
#  ('светом', 0.8265318274497986),
#  ('мученицы', 0.825559139251709)]

# %%
model.most_similar('веселый')
# Out:
# [('смех', 0.7946944236755371),
#  ('красивый', 0.7780161499977112),
#  ('любимый', 0.7752023339271545),
#  ('радостно', 0.7749467492103577),
#  ('закричал', 0.7743536233901978),
#  ('зверь', 0.7723735570907593),
#  ('полна', 0.772318959236145),
#  ('впечатление', 0.7718466520309448),
#  ('умрет', 0.7714648246765137),
#  ('выйдет', 0.7694040536880493)]

# %%
model.most_similar('необхідно')
# Out:
# [('потрібно', 0.9030581712722778),
#  ('треба', 0.8139247894287109),
#  ('доцільно', 0.6586316823959351),
#  ('важливо', 0.657439112663269),
#  ('мусити', 0.6352549195289612),
#  ('повинний', 0.6283621191978455),
#  ('слід', 0.617668628692627),
#  ('можна', 0.6162741780281067),
#  ('необхідне', 0.6128346920013428),
#  ('варто', 0.6104767322540283)]

# %%
model.most_similar('біткоін')
# Out:
# [('біткойн', 0.5037258863449097),
#  ('bitcoin', 0.5013667345046997),
#  ('біткойни', 0.4744699001312256),
#  ('біткоїни', 0.46457451581954956),
#  ('біткоіни', 0.4625184237957001),
#  ('криптовалюти', 0.4498669505119324),
#  ('біткоінів', 0.43722742795944214),
#  ('неконвертований', 0.4350539445877075),
#  ('біткоїнів', 0.41223546862602234),
#  ('інвалюта', 0.4116742014884949)]

# %%
model.most_similar('криптовалюти')
# Out:
# [('bitcoin', 0.6192612051963806),
#  ('біткоінів', 0.6086275577545166),
#  ('криптовалюта', 0.5554796457290649),
#  ('читалка', 0.5179547071456909),
#  ('месенджера', 0.5172154307365417),
#  ('антивіруса', 0.5137486457824707),
#  ('біткоїни', 0.5131414532661438),
#  ('смарт-карта', 0.5099830627441406),
#  ('біткоїнів', 0.509772539138794),
#  ('веб-сервіс', 0.5040185451507568)]

# %%
model.most_similar('ефір')
# Out:
# [('телеефір', 0.7178679704666138),
#  ("інтерв'ю", 0.6808054447174072),
#  ('ефірі_', 0.6549076437950134),
#  ('радіоефір', 0.5611504316329956),
#  ('ефiрi', 0.5476671457290649),
#  ("інтерв'ю_", 0.5451374650001526),
#  ('ток-шоу', 0.534655749797821),
#  ('прайм-тайм', 0.5317953824996948),
#  ('етер', 0.5301365852355957),
#  ('ефірі**', 0.5250378251075745)]

# %%
model.most_similar('ведучий')
# Out:
# [('телеведучий', 0.7095372676849365),
#  ('співведучим', 0.697087287902832),
#  ('співведучий', 0.6752596497535706),
#  ('екс-ведучий', 0.6570297479629517),
#  ('радіоведучий', 0.640015184879303),
#  ('диктор', 0.5921870470046997),
#  ('шеф-редактор', 0.5898866057395935),
#  ('співведуча', 0.5895422697067261),
#  ('генпродюсер', 0.5852927565574646),
#  ('телевізійний', 0.58371901512146)]

# %%
model.most_similar('1+1')
# Out:
# [('стб', 0.7609527707099915),
#  ('інтер', 0.7344126105308533),
#  ('ictv', 0.7134978771209717),
#  ('тет', 0.7101826667785645),
#  ('нтн', 0.7027866244316101),
#  ('тві', 0.693223237991333),
#  ('1+1_', 0.6874771118164062),
#  ('_1+1_', 0.686276376247406),
#  ('тоніс', 0.657219648361206),
#  ('ут-1', 0.6477735042572021)]

# %%
model.similar_by_vector('ведучий')
# Out:
# [('телеведучий', 0.7095372676849365),
#  ('співведучим', 0.697087287902832),
#  ('співведучий', 0.6752596497535706),
#  ('екс-ведучий', 0.6570297479629517),
#  ('радіоведучий', 0.640015184879303),
#  ('диктор', 0.5921870470046997),
#  ('шеф-редактор', 0.5898866057395935),
#  ('співведуча', 0.5895422697067261),
#  ('генпродюсер', 0.5852927565574646),
#  ('телевізійний', 0.58371901512146)]

# %%
model.most_similar(positive=['павук', 'ссавець'], negative=['лис'])
# Out:
# [('плазун', 0.6657742261886597),
#  ('комаха', 0.6243432760238647),
#  ('молюск', 0.617104172706604),
#  ('павукоподібний', 0.6166720390319824),
#  ('гризун', 0.6131504774093628),
#  ('рептилія', 0.6016244888305664),
#  ('ракоподібний', 0.5958621501922607),
#  ('безхребетний', 0.59438556432724),
#  ('китоподібні', 0.58200603723526),
#  ('черевоногі', 0.5775234699249268)]

# %%
model.most_similar(positive=['павук', 'ссавець'], negative=['панда'])
# Out:
# [('комаха', 0.635698676109314),
#  ('павукоподібний', 0.6329059600830078),
#  ('молюск', 0.6157327890396118),
#  ('плазун', 0.5908076167106628),
#  ('черевоногі', 0.586063802242279),
#  ('безхребетний', 0.5857506990432739),
#  ('членистоногі', 0.579708456993103),
#  ('голкошкірий', 0.5734820365905762),
#  ('багатоніжка', 0.5702904462814331),
#  ('земноводні', 0.5687847137451172)]

# %%
model.most_similar(positive=['павук', 'ссавець'], negative=['горила'])
# Out:
# [('комаха', 0.6125459671020508),
#  ('плазун', 0.5827335119247437),
#  ('молюск', 0.5808213949203491),
#  ('павукоподібний', 0.5747575759887695),
#  ('птах', 0.5346301198005676),
#  ('гризун', 0.5308268666267395),
#  ('кліщ', 0.5302947163581848),
#  ('ракоподібний', 0.5217846632003784),
#  ('паразит', 0.5170093774795532),
#  ('голкошкірий', 0.5165128111839294)]

# %%
model.most_similar(positive=['павук', 'ссавець'], negative=['мавпа'])
# Out:
# [('плазун', 0.6322662830352783),
#  ('молюск', 0.6098107695579529),
#  ('павукоподібний', 0.607039213180542),
#  ('черевоногі', 0.5983912944793701),
#  ('членистоногі', 0.5932478308677673),
#  ('комаха', 0.5863272547721863),
#  ('земноводний', 0.5682198405265808),
#  ('лускокрилі', 0.5619215965270996),
#  ('земноводні', 0.5617378950119019),
#  ('безхребетний', 0.5549312829971313)]

# %%
model.most_similar(positive=['павук', 'ссавець'], negative=['собака'])
# Out:
# [('павукоподібний', 0.6486901640892029),
#  ('плазун', 0.6268360614776611),
#  ('черевоногі', 0.6033906936645508),
#  ('двокрилий', 0.5900319218635559),
#  ('земноводні', 0.5877562761306763),
#  ('павукоподібні', 0.5874106884002686),
#  ('членистоногі', 0.5861859321594238),
#  ('сумчасті', 0.5815554857254028),
#  ('птерозавр', 0.5779517292976379),
#  ('молюск', 0.576275110244751)]

# %%
model.similar_by_vector('мати')
# Out:
# [('малий', 0.6940096020698547),
#  ('маючи', 0.6342123746871948),
#  ('мая', 0.5776592493057251),
#  ('давати', 0.5585447549819946),
#  ('мало', 0.48780128359794617),
#  ('володіти', 0.47749465703964233),
#  ('наділений', 0.4746468961238861),
#  ('маючий', 0.47442373633384705),
#  ('**має', 0.4648120701313019),
#  ('втратити', 0.44373515248298645)]

# %%
model.similar_by_vector('матюк')
# Out:
# [('лайка', 0.7279493808746338),
#  ('нецензурщина', 0.7015808820724487),
#  ('нецензурний', 0.6804293990135193),
#  ('лайливий', 0.6360175609588623),
#  ('ненормативний', 0.6138516664505005),
#  ('русизм', 0.6005114316940308),
#  ('проклін', 0.5742270946502686),
#  ('матірний', 0.5650333166122437),
#  ('викрик', 0.5611050128936768),
#  ('суржик', 0.5559477806091309)]

# %%
model.similar_by_vector('матюкати')
# Out:
# [('хамити', 0.703264057636261),
#  ('облаяти', 0.6788617372512817),
#  ('лупцювати', 0.669232189655304),
#  ('матюкатися', 0.6542124152183533),
#  ('грубіянити', 0.643416166305542),
#  ('вилаяти', 0.6428841352462769),
#  ('обзивати', 0.6295390725135803),
#  ('обматюкав', 0.6220752000808716),
#  ('дубасити', 0.6169849634170532),
#  ('лаяти', 0.614028811454773)]

# %%
model.similar_by_vector('бути')
# Out:
# [('булий', 0.7061047554016113),
#  ('виявитися', 0.5732749700546265),
#  ('вважатися', 0.5288889408111572),
#  ('виявлятися', 0.48987019062042236),
#  ('існувати', 0.43964534997940063),
#  ('знайтися', 0.4341072738170624),
#  ('ставати', 0.43004098534584045),
#  ('мати', 0.4012618064880371),
#  ('стати', 0.39622437953948975),
#  ('залишатися', 0.39187246561050415)]

# %%
model.similar_by_vector('батько')
# Out:
# [('вітчим', 0.7677429914474487),
#  ('мама', 0.7640690207481384),
#  ('тато', 0.7562926411628723),
#  ('батьки', 0.7504791021347046),
#  ('син', 0.7406424283981323),
#  ('дружина', 0.7325749397277832),
#  ('дідусь', 0.729518473148346),
#  ('онука', 0.7226213812828064),
#  ('батьків', 0.7200278043746948),
#  ('бабуся', 0.7187635898590088)]
